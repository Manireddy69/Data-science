# %% [markdown]
# <a href="https://colab.research.google.com/github/Manireddy69/Data-science/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
df = np.array([[1,2,3,4],
               [5,6,7,8]])

# %%
df[:, 0] #columns(starting from index = 0)
df[1] #Rows
df[0][0]  #[Row][column]
# Out:
# np.int64(1)

# %%
b2 = df.copy() # FULL copy of an array
df[0] = [1,2,4,5]
# Out:
# array([[1, 2, 4, 5],
#        [5, 6, 7, 8]])

# %%
one = np.ones((3,3), dtype= int)
identity = np.eye(3, dtype = int)

# %%
np.array((identity/ one), dtype = int)
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
df = np.random.RandomState(42).randint(1,10, (3,3)) #Randomstate(42) is to keep elements fixed
df
# Out:
# array([[7, 4, 8],
#        [5, 7, 3],
#        [7, 8, 5]])

# %%
np.sum(df,axis = 0) # sum of each column
np.sum(df, axis = 1) # sum of each row
# Out:
# array([19, 15, 20])

# %%
df = np.random.RandomState(42).randint(10,size = 5)
df
# Out:
# array([6, 3, 7, 4, 6])

# %%
df.max()
df.min()
df.mean()
df.sum()
# Out:
# np.int64(26)

# %%
#then how does this works on 2-d array

# %%
df = np.random.RandomState(42).randint(1,10,(2,2))
df
# Out:
# array([[7, 4],
#        [8, 5]])

# %%
df.max()
df.mean()
df.max()
df.sum()   # works same as 1-d array
# Out:
# np.int64(24)

# %%
df = np.array([1,1,2,2,2,3,3,4,5,6,7,7,7,8,8])
np.unique(df, return_index = True) #gives unique elements & indexes of it.
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), array([ 0,  2,  5,  7,  8,  9, 10, 13]))

# %%
np.unique(df, return_counts = True) #same: give unique and counts of the each element
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), array([2, 3, 2, 1, 1, 1, 3, 2]))

# %%
m = np.random.RandomState(42).randint(1,10, size =(2,3))

# %%
m2 = np.arange(6).reshape(2,3) ## Becareful with arange(num) takes only #of elements in the matrix.

# %%
import numpy as np
d = np.array([[1,2,3,3,4],
              [1,2,3,4,3]])

# %%
np.shape(d)
# Out:
# (2, 5)

# %%
np.save('first',d) # Saves the array 'd' to 'first.npy' in the Colab environment.

# %%
b = np.load('first.npy')

# %%
#even we can convert numpy array into Dataframe
import pandas as pd

# %%
df = pd.DataFrame(d, index = list(range(1,3)), dtype= int, columns= list(range(1,6)))
df
# Out:
#    1  2  3  4  5
# 1  1  2  3  3  4
# 2  1  2  3  4  3

# %%
# Out:
# 1    2
# 2    2
# Name: 2, dtype: int64
